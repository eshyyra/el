# %% [markdown]
# <a href="https://colab.research.google.com/github/eshyyra/el/blob/main/H081221006_Elvia_Shyra_TUGAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dataset = '/content/sdg_index_2000-2022 (1).csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#      country_code      country  year  sdg_index_score  goal_1_score  \
# 0             AFG  Afghanistan  2000             36.0          28.8
# 1             AFG  Afghanistan  2001             36.3          28.8
# 2             AFG  Afghanistan  2002             36.3          28.8
# 3             AFG  Afghanistan  2003             36.7          28.8
# 4             AFG  Afghanistan  2004             37.1          28.8
# ...           ...          ...   ...              ...           ...
# 4135          ZWE     Zimbabwe  2018             55.9          26.4
# 4136          ZWE     Zimbabwe  2019             53.7          21.4
# 4137          ZWE     Zimbabwe  2020             54.3          20.1
# 4138          ZWE     Zimbabwe  2021             54.8          20.8
# 4139          ZWE     Zimbabwe  2022             55.6          21.5
#
#       goal_2_score  goal_3_score  goal_4_score  goal_5_score  goal_6_score  \
# ...

# %%
data.head()
# Out:
#   country_code      country  year  sdg_index_score  goal_1_score  \
# 0          AFG  Afghanistan  2000             36.0          28.8
# 1          AFG  Afghanistan  2001             36.3          28.8
# 2          AFG  Afghanistan  2002             36.3          28.8
# 3          AFG  Afghanistan  2003             36.7          28.8
# 4          AFG  Afghanistan  2004             37.1          28.8
#
#    goal_2_score  goal_3_score  goal_4_score  goal_5_score  goal_6_score  ...  \
# 0          27.3          19.2           1.6          20.8          32.4  ...
# 1          30.6          19.4           1.6          20.8          32.4  ...
# 2          30.7          19.7           1.6          20.8          32.7  ...
# 3          32.5          19.9           1.6          20.8          33.0  ...
# 4          32.1          21.1           1.6          20.8          33.3  ...
#
#    goal_8_score  goal_9_score  goal_10_score  goal_11_score  goal_12_score  \
# ...

# %%
print(data.dtypes)
# Out:
# country_code        object
# country             object
# year                 int64
# sdg_index_score    float64
# goal_1_score       float64
# goal_2_score       float64
# goal_3_score       float64
# goal_4_score       float64
# goal_5_score       float64
# goal_6_score       float64
# goal_7_score       float64
# goal_8_score       float64
# goal_9_score       float64
# goal_10_score      float64
# goal_11_score      float64
# goal_12_score      float64
# goal_13_score      float64
# goal_14_score      float64
# goal_15_score      float64
# goal_16_score      float64
# goal_17_score      float64
# dtype: object

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#      country_code      country  year  sdg_index_score  goal_2_score  \
# 0             AFG  Afghanistan  2000             36.0          27.3
# 1             AFG  Afghanistan  2001             36.3          30.6
# 2             AFG  Afghanistan  2002             36.3          30.7
# 3             AFG  Afghanistan  2003             36.7          32.5
# 4             AFG  Afghanistan  2004             37.1          32.1
# ...           ...          ...   ...              ...           ...
# 4135          ZWE     Zimbabwe  2018             55.9          46.6
# 4136          ZWE     Zimbabwe  2019             53.7          46.0
# 4137          ZWE     Zimbabwe  2020             54.3          47.2
# 4138          ZWE     Zimbabwe  2021             54.8          48.4
# 4139          ZWE     Zimbabwe  2022             55.6          48.5
#
#       goal_3_score  goal_4_score  goal_5_score  goal_6_score  goal_7_score  \
# ...

# %%
data.describe()
# Out:
#               year  sdg_index_score  goal_1_score  goal_2_score  goal_3_score  \
# count  4140.000000      4140.000000   4140.000000   4140.000000   4140.000000
# mean   2011.000000        63.685435     64.815628     57.735531     64.045652
# std       6.634051        10.776469     36.098836     11.121524     22.354993
# min    2000.000000        36.000000      0.000000      7.700000      5.900000
# 25%    2005.000000        55.075000     31.500000     52.400000     44.800000
# 50%    2011.000000        65.100000     81.000000     58.900000     70.200000
# 75%    2017.000000        72.000000     98.600000     65.300000     81.300000
# max    2022.000000        86.800000    100.000000     83.400000     97.300000
#
#        goal_4_score  goal_5_score  goal_6_score  goal_7_score  goal_8_score  \
# count   4140.000000   4140.000000   4140.000000   4140.000000   4140.000000
# mean      71.990048     55.803309     63.963188     57.340966     69.839493
# ...

# %%
data.loc[:,"sdg_index_score":].corr()
# Out:
#                  sdg_index_score  goal_1_score  goal_2_score  goal_3_score  \
# sdg_index_score         1.000000      0.721831      0.681556      0.915972
# goal_1_score            0.721831      1.000000      0.406386      0.645959
# goal_2_score            0.681556      0.406386      1.000000      0.613301
# goal_3_score            0.915972      0.645959      0.613301      1.000000
# goal_4_score            0.862871      0.610335      0.588729      0.841803
# goal_5_score            0.713667      0.392725      0.530523      0.614763
# goal_6_score            0.863086      0.652195      0.624116      0.788921
# goal_7_score            0.877793      0.616710      0.554160      0.867888
# goal_8_score            0.734385      0.441130      0.605815      0.689743
# goal_9_score            0.813956      0.530886      0.608299      0.804341
# goal_10_score           0.440414      0.444877      0.155985      0.284739
# ...

# %%
# @title sdg_index_score VS goal_1_score

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='sdg_index_score', y='goal_1_score', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# **Dengan API**

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-0bbef29d-120e-456c-9324-5b1967fca3a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0bbef29d-120e-456c-9324-5b1967fca3a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "goal Sustainable"
# Out:
# ...
# ref                                                          title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# -----------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# anshtanwar/global-data-on-sustainable-energy                 Global Data on Sustainable Energy (2000-2020)      174KB  2023-08-19 05:22:23          12292        179  1.0
# sazidthe1/sustainable-development-report                     Sustainable Development Data up to 2023            142KB  2023-09-18 12:50:07           2059         49  1.0
# footprintnetwork/national-footprint-accounts-2018            National Footprint Accounts 2018                     3MB  2018-07-11 18:26:33           3675        123  0.85294116
# ...

# %%
# !kaggle datasets download sazidthe1/sustainable-development-report
# Out:
# ...
#   0% 0.00/142k [00:00<?, ?B/s]
# 100% 142k/142k [00:00<00:00, 65.8MB/s]

# %%
# !unzip /content/sustainable-development-report.zip
# Out:
# Archive:  /content/sustainable-development-report.zip
#   inflating: sdg_index_2000-2022.csv
#   inflating: sustainable_development_report_2023.csv

# %%
pd.read_csv('/content/sustainable_development_report_2023.csv')
# Out:
#     country_code                   country              region  overall_score  \
# 0            FIN                   Finland                OECD      86.760595
# 1            SWE                    Sweden                OECD      85.981397
# 2            DNK                   Denmark                OECD      85.683637
# 3            DEU                   Germany                OECD      83.358447
# 4            AUT                   Austria                OECD      82.280189
# ..           ...                       ...                 ...            ...
# 161          SOM                   Somalia  Sub-Saharan Africa      48.027231
# 162          YEM               Yemen, Rep.                MENA      46.846980
# 163          TCD                      Chad  Sub-Saharan Africa      45.342321
# 164          CAF  Central African Republic  Sub-Saharan Africa      40.395839
# 165          SSD               South Sudan  Sub-Saharan Africa      38.676086
#
# ...
